# %% [markdown]
# DATA-SCIENCE INTERNSHIP AT DATA GLACIER
#
# PROJECT NAME: Predicting the persistency of a drug (Healthcare) - WEEK 7
#
# PROBLEM DESCRIPTION
#
# Pharmaceutical companies are going through the challange of understanding the persistency of drug as per the physician prescription. ABC pharma company has approached our analytics company to automate this process of identification by gathering insights on the factors that are impacting the persistency.

# %% [markdown]
# loading dataset and feature desctiption sheet

# %%
import pandas as pd

# %% [markdown]
# df1 represents Dataset and df2 represents Feature Description

# %%
main_dataset= pd.read_excel("Healthcare_dataset.xlsx", sheet_name= "Dataset")

# %%
df2= pd.read_excel("Healthcare_dataset.xlsx", sheet_name= "Feature Description")

# %% [markdown]
# Number of Rows and columns present in the main dataset

# %%
print("Number of rows in Dataset : {}".format(len(main_dataset)))
print("Number of features in Dataset: {}".format(len(main_dataset.columns)))
print("The shape of the Dataset:{}".format(main_dataset.shape))
# Out:
# Number of rows in Dataset : 3424
# Number of features in Dataset: 69
# The shape of the Dataset:(3424, 69)

# %%
main_dataset.info
# Out:
# <bound method DataFrame.info of        Ptid Persistency_Flag  Gender           Race     Ethnicity   Region  \
# 0        P1       Persistent    Male      Caucasian  Not Hispanic     West
# 1        P2   Non-Persistent    Male          Asian  Not Hispanic     West
# 2        P3   Non-Persistent  Female  Other/Unknown      Hispanic  Midwest
# 3        P4   Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# 4        P5   Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# ...     ...              ...     ...            ...           ...      ...
# 3419  P3420       Persistent  Female      Caucasian  Not Hispanic    South
# 3420  P3421       Persistent  Female      Caucasian  Not Hispanic    South
# 3421  P3422       Persistent  Female      Caucasian  Not Hispanic    South
# 3422  P3423   Non-Persistent  Female      Caucasian  Not Hispanic    South
# 3423  P3424   Non-Persistent  Female      Caucasian  Not Hispanic    South
#
# ...

# %% [markdown]
# Inspecting columns of Main Dataset

# %%
main_dataset.iloc[:,:25]
# Out:
#        Ptid Persistency_Flag  Gender           Race     Ethnicity   Region  \
# 0        P1       Persistent    Male      Caucasian  Not Hispanic     West
# 1        P2   Non-Persistent    Male          Asian  Not Hispanic     West
# 2        P3   Non-Persistent  Female  Other/Unknown      Hispanic  Midwest
# 3        P4   Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# 4        P5   Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# ...     ...              ...     ...            ...           ...      ...
# 3419  P3420       Persistent  Female      Caucasian  Not Hispanic    South
# 3420  P3421       Persistent  Female      Caucasian  Not Hispanic    South
# 3421  P3422       Persistent  Female      Caucasian  Not Hispanic    South
# 3422  P3423   Non-Persistent  Female      Caucasian  Not Hispanic    South
# 3423  P3424   Non-Persistent  Female      Caucasian  Not Hispanic    South
#
#      Age_Bucket        Ntm_Speciality Ntm_Specialist_Flag  \
# ...

# %%
main_dataset.iloc[:,25:50]
# Out:
#      Comorb_Encounter_For_Screening_For_Malignant_Neoplasms  \
# 0                                                     N
# 1                                                     N
# 2                                                     Y
# 3                                                     N
# 4                                                     Y
# ...                                                 ...
# 3419                                                  Y
# 3420                                                  N
# 3421                                                  Y
# 3422                                                  Y
# 3423                                                  N
#
#      Comorb_Encounter_For_Immunization  \
# 0                                    Y
# 1                                    N
# 2                                    N
# 3                                    Y
# 4                                    Y
# ...                                ...
# ...

# %%
main_dataset.iloc[:,50:]
# Out:
#      Risk_Osteogenesis_Imperfecta Risk_Rheumatoid_Arthritis  \
# 0                               N                         N
# 1                               N                         N
# 2                               N                         N
# 3                               N                         N
# 4                               N                         N
# ...                           ...                       ...
# 3419                            N                         N
# 3420                            N                         N
# 3421                            N                         N
# 3422                            N                         N
# 3423                            N                         N
#
#      Risk_Untreated_Chronic_Hyperthyroidism  \
# 0                                         N
# 1                                         N
# 2                                         N
# 3                                         N
# ...

# %% [markdown]
# Checking for the Max risk Value

# %%
main_dataset.sort_values("Count_Of_Risks").iloc[61:]
# Out:
#        Ptid Persistency_Flag  Gender              Race     Ethnicity  \
# 916    P917       Persistent    Male         Caucasian  Not Hispanic
# 2445  P2446   Non-Persistent  Female         Caucasian  Not Hispanic
# 913    P914   Non-Persistent  Female         Caucasian  Not Hispanic
# 2453  P2454   Non-Persistent  Female         Caucasian       Unknown
# 2355  P2356   Non-Persistent  Female         Caucasian  Not Hispanic
# ...     ...              ...     ...               ...           ...
# 3340  P3341       Persistent  Female         Caucasian  Not Hispanic
# 3146  P3147   Non-Persistent  Female         Caucasian  Not Hispanic
# 2601  P2602   Non-Persistent  Female         Caucasian  Not Hispanic
# 1059  P1060   Non-Persistent  Female         Caucasian  Not Hispanic
# 817    P818       Persistent  Female  African American  Not Hispanic
#
#          Region Age_Bucket        Ntm_Speciality Ntm_Specialist_Flag  \
# ...

# %% [markdown]
# checking feature description

# %%
df2
# Out:
#                       Bucket                             Variable  \
# 0              Unique Row Id                           Patient ID
# 1            Target Variable                     Persistency_Flag
# 2               Demographics                                  Age
# 3                        NaN                                 Race
# 4                        NaN                               Region
# 5                        NaN                            Ethnicity
# 6                        NaN                               Gender
# 7                        NaN                        IDN Indicator
# 8        Provider Attributes            NTM - Physician Specialty
# 9           Clinical Factors                       NTM - T-Score
# 10                       NaN                   Change in T Score
# 11                       NaN                   NTM - Risk Segment
# 12                       NaN               Change in Risk Segment
# ...

# %% [markdown]
# Checking for datatypes of all features present in Main_Dataset

# %%
main_dataset.dtypes[0:40]
# Out:
# Ptid                                                                  object
# Persistency_Flag                                                      object
# Gender                                                                object
# Race                                                                  object
# Ethnicity                                                             object
# Region                                                                object
# Age_Bucket                                                            object
# Ntm_Speciality                                                        object
# Ntm_Specialist_Flag                                                   object
# Ntm_Speciality_Bucket                                                 object
# Gluco_Record_Prior_Ntm                                                object
# Gluco_Record_During_Rx                                                object
# ...

# %%
main_dataset.dtypes[40:]
# Out:
# Concom_Narcotics                                object
# Concom_Systemic_Corticosteroids_Plain           object
# Concom_Anti_Depressants_And_Mood_Stabilisers    object
# Concom_Fluoroquinolones                         object
# Concom_Cephalosporins                           object
# Concom_Macrolides_And_Similar_Types             object
# Concom_Broad_Spectrum_Penicillins               object
# Concom_Anaesthetics_General                     object
# Concom_Viral_Vaccines                           object
# Risk_Type_1_Insulin_Dependent_Diabetes          object
# Risk_Osteogenesis_Imperfecta                    object
# Risk_Rheumatoid_Arthritis                       object
# Risk_Untreated_Chronic_Hyperthyroidism          object
# Risk_Untreated_Chronic_Hypogonadism             object
# Risk_Untreated_Early_Menopause                  object
# Risk_Patient_Parent_Fractured_Their_Hip         object
# Risk_Smoking_Tobacco                            object
# ...

# %% [markdown]
# Checking for duplicate values and missing values

# %%
main_dataset.isna().sum()[0:40]
# Out:
# Ptid                                                                  0
# Persistency_Flag                                                      0
# Gender                                                                0
# Race                                                                  0
# Ethnicity                                                             0
# Region                                                                0
# Age_Bucket                                                            0
# Ntm_Speciality                                                        0
# Ntm_Specialist_Flag                                                   0
# Ntm_Speciality_Bucket                                                 0
# Gluco_Record_Prior_Ntm                                                0
# Gluco_Record_During_Rx                                                0
# Dexa_Freq_During_Rx                                                   0
# ...

# %%
main_dataset.isna().sum().iloc[40:]
# Out:
# Concom_Narcotics                                0
# Concom_Systemic_Corticosteroids_Plain           0
# Concom_Anti_Depressants_And_Mood_Stabilisers    0
# Concom_Fluoroquinolones                         0
# Concom_Cephalosporins                           0
# Concom_Macrolides_And_Similar_Types             0
# Concom_Broad_Spectrum_Penicillins               0
# Concom_Anaesthetics_General                     0
# Concom_Viral_Vaccines                           0
# Risk_Type_1_Insulin_Dependent_Diabetes          0
# Risk_Osteogenesis_Imperfecta                    0
# Risk_Rheumatoid_Arthritis                       0
# Risk_Untreated_Chronic_Hyperthyroidism          0
# Risk_Untreated_Chronic_Hypogonadism             0
# Risk_Untreated_Early_Menopause                  0
# Risk_Patient_Parent_Fractured_Their_Hip         0
# Risk_Smoking_Tobacco                            0
# Risk_Chronic_Malnutrition_Or_Malabsorption      0
# Risk_Chronic_Liver_Disease                      0
# ...
